# %% [markdown]
# <a href="https://colab.research.google.com/github/highlandnate2005-ui/MIS2800/blob/main/IC2_1_Highland.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("OneNote Enviornment Ready")
# Out:
# OneNote Enviornment Ready
